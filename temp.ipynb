# %%
from basic_cleaner import clean

# %%
url= "https://huggingface.co/docs/transformers/main/en/model_doc/llama2"
s= clean(url)

s
# Out:
# 'Llama2                       Solutions                  Transformers documentation     Llama2           Transformers          Search documentation   mainv4.31.0v4.30.0v4.29.1v4.28.1v4.27.2v4.26.1v4.25.1v4.24.0v4.23.1v4.22.2v4.21.3v4.20.1v4.19.4v4.18.0v4.17.0v4.16.2v4.15.0v4.14.1v4.13.0v4.12.5v4.11.3v4.10.1v4.9.2v4.8.2v4.7.0v4.6.0v4.5.1v4.4.2v4.3.3v4.2.2v4.1.1v4.0.1v3.5.1v3.4.0v3.3.1v3.2.0v3.1.0v3.0.2v2.11.0v2.10.0v2.9.1v2.8.0v2.7.0v2.6.0v2.5.1v2.4.1v2.3.0v2.2.2v2.1.1v2.0.0v1.2.0v1.1.0v1.0.0doc-builder-html DEENESFRITKOPTZH        Get started     Tutorials     Task Guides    Natural Language Processing   Audio   Computer Vision   Multimodal   Generation    Developer guides     Performance and scalability    Efficient training techniques     Optimizing inference      Contribute     Conceptual guides     API    Main Classes     Models    Text models     Vision models   Audio models   Multimodal models   Reinforcement learning models   Time series models   Graph models    Internal Helpe
# ...

# %%
url= "https://github.com/facebookresearch/llama"
print(clean(url))
# Out:
# GitHub - facebookresearch/llama: Inference code for LLaMA models                                                          Toggle navigation                                Product                                   Explore                        Solutions               For             By Solution           Resources                      Open Source                           Repositories                          Search or jump to...        Search code, repositories, users, issues, pull requests...                Search                     Clear                                                          Provide feedback                  We read every piece of feedback, and take your input very seriously.   Include my email address so I can be contacted       Cancel      Submit feedback                   Saved searches        Use saved searches to filter your results more quickly                Name       Query                To see all available qualifiers, see our .                       
# ...

# %%
url= "https://huggingface.co/docs/transformers/main/en/model_doc/llama2"
gen_text= (clean(url))

# %%
with open('x.txt', 'w') as f:
    f.write(clean(url))

# %%
len(gen_text)
# Out:
# 33164
