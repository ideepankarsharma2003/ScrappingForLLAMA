# %% [markdown]
# # Spyfu

# %%
# url= "https://www.headphonesty.com/2018/11/best-cat-ear-headphones/"
url= "https://www.androidauthority.com/best-android-emulators-for-pc-655308/"

# %%
from organic_keywords import organic_keywords_extractor

original_keywords= organic_keywords_extractor.extract_organic_keywords(url)
original_keywords
# Out:
# ['emulator for android games on pc',
#  'mobile emulator app',
#  'best laptop emulator',
#  'android emulator laptop',
#  'android emulator for mobile',
#  'emulator for android to pc',
#  'pc to android emulator',
#  'android app players',
#  'phone emulator pc',
#  'world best emulator for pc',
#  'android games emulator pc',
#  'apk emulator for pc',
#  'fastest android emulator for pc 2020',
#  'best android pc',
#  'android emulators for windows',
#  'best android app emulator',
#  'free mobile emulator',
#  'android emulators for pc',
#  'android phone emulator',
#  'best apk player for pc',
#  'best mobile emulators for pc',
#  'virtual mobile phone on pc',
#  'emulator for free',
#  'android emulator for desktop',
#  'mobile emulators for pc',
#  'best android emulator mac',
#  'pc emulator android apk',
#  'virtual android phone on pc',
#  'emulator for gaming',
#  'pc emulator app',
#  'android vm for windows',
#  'android apps emulator for pc',
#  'pc phone emulator',
#  'android os emulator',
#  'emulator android for windows',
#  'mobile gaming mouse for pc android emulators',
#  'the best android emulators',
#  'top emulator pc',
#  'android games on pc emulator',
#  'android emulator free',
#  'mobile android emulator for pc',
#  'mobile gaming mouse for pc android emulators free',
#  'best android simulators',
#  'mobile apps on pc emulator',
#  'android phone emulator for mac',
#  'emulator mobile',
#  'best emulator pc android',
#  'best android emulator',
#  'android app player for pc',
#  'android emulator for laptop',
#  'best phone emulator 2022',
#  'android p emulator',
#  'android computer emulator',
#  'android virtual machine for windows',
#  'android for pc emulator',
#  'mobile phone emulator download',
#  'mobile phone emulator for pc',
#  'phone emulator for pc',
#  'pc apk emulator',
#  'emulator pc android',
#  'phone emulators for pc',
#  'pc app emulator',
#  'apk game player for pc',
#  'mobile phone emulators',
#  'android 9 emulator',
#  'pc android emulator',
#  'smart phone emulator',
#  'best free emulator',
#  'android emulator for pc free',
#  'smartphone emulator',
#  'android emulator for games',
#  'emulator app android for pc',
#  'top emulator',
#  'android emu',
#  'android emulators download',
#  'good android emulator',
#  'android emulater',
#  'android apps emulator',
#  'phone emulator',
#  'android pc emulator free',
#  'emulator for android apps on pc',
#  'gaming pc emulator for android',
#  'android games emulator for pc',
#  'emulators android for pc',
#  'best android emulator for gaming',
#  'pc emulator android',
#  'android phone simulator',
#  'android pc games emulator',
#  'best mobile emulators',
#  'best android emulators pc',
#  'android player pc',
#  'android desktop emulator',
#  'emulator for pc apk',
#  'game emulator android for pc',
#  'android phone emulator mac',
#  'best phone emulator',
#  'best android emulator for pc for gaming',
#  'game pc emulator for android',
#  'android app player in pc',
#  'new android emulator',
#  'top android emulator',
#  'best pc android emulator',
#  'android apps pc emulator',
#  'best android emulator 2022',
#  'mobile emulater',
#  'pc game android emulator',
#  'android games to pc emulator',
#  'better android emulator',
#  'mobile emulator free',
#  'android app emulators',
#  'os emulator for windows',
#  'mobile emulators',
#  'best android emulator for games',
#  'best phone emulator for pc',
#  'apk emulator for windows',
#  'emu android',
#  'app emulator',
#  'apk emulator',
#  'best android emulator windows',
#  'emulator for mobile games',
#  'emulate android on windows',
#  'android game emulator for pc',
#  'best android pc emulator',
#  'emulator android to pc',
#  'android app player',
#  'android emulator for gaming',
#  'emulate android on pc',
#  'top best emulator for pc',
#  'google emulator for pc',
#  'mobile gaming mouse for pc android emulators 2017',
#  'emulator android windows',
#  'best mobile games emulator',
#  'android mobile emulator',
#  'apk emulator windows',
#  'the best android emulators for pc',
#  'best play store emulator for pc',
#  'emulator android for pc',
#  'android phone emulator for pc',
#  'android pc emulator',
#  'emulator for apk',
#  'app emulation',
#  'best android emulators',
#  'android app emulator',
#  'android player for windows',
#  'the best android emulator',
#  'best app emulator',
#  'best android emulator pc',
#  'android pc game emulator',
#  'cell phone emulator for pc',
#  'android emulator pc for games',
#  'mobile phone emulator for windows',
#  'free android emulator for mac',
#  'emulator for pc to run android apps',
#  'mobile app emulator',
#  'phone games emulator',
#  'mobile emulator mac',
#  'pc emulator for android games',
#  'best windows android emulator',
#  'free android emulator',
#  'android game for pc emulator',
#  'windows android emulator for pc',
#  'emu android pc',
#  'best emulator for running android apps on pc',
#  'best emulator to run android apps on pc',
#  'android phone emulator for windows',
#  'best android emulator for windows',
#  'window android emulator',
#  'top pc emulator',
#  'emulator android on pc',
#  'emulator android games for pc',
#  'android emulator for',
#  'emulator for pc android',
#  'emulator pc apk',
#  'android app emulator for pc',
#  'google play emulator for pc',
#  '!emu android',
#  'top android emulators',
#  'android pc emulator apk',
#  'google play store emulator for pc',
#  'download android emulator for',
#  'virtual android on windows',
#  'android pc emulator for games',
#  'android emulator for pc',
#  'android emulators',
#  'best android emulator macos',
#  'virtual android pc',
#  'android emulator software',
#  'best android game emulator for windows 10',
#  'mobile games emulator for pc',
#  'free emulator android',
#  'android emulator for pc games',
#  'android emulator on pc',
#  'android player for pc',
#  'mobile phone emulator',
#  'emulator phone',
#  'emulator pc for android',
#  'best free android emulator',
#  'best android emulators on pc',
#  'best android emulator on pc',
#  'android emulator for windows',
#  'mobile emulator software',
#  'google pixel emulator pc',
#  'android apps emulator for windows',
#  'android apk pc emulator',
#  'android emulators free',
#  'top 15 android emulator for pc',
#  'mac android emulator',
#  'best app for android games on pc',
#  'free phone emulator',
#  'emulator for android on pc',
#  'os emulator',
#  'pc emulator google play',
#  'best emulator android for pc',
#  'best android emulators for pc',
#  'best emulator for android on pc',
#  'android runner for pc',
#  'android emulator pc free',
#  'android apk emulator for pc',
#  'emulator for',
#  'phone emulator on pc',
#  'best emulator android games on pc',
#  'android games in pc emulator',
#  'top free android emulator for pc',
#  'best emulator for',
#  'emulator app',
#  'best android emulator for game',
#  'android emulators for pc download',
#  'apk for pc emulator',
#  'the best android emulators on pc',
#  'android emulator windows',
#  'android app player pc',
#  'android apps player',
#  'cell phone emulator',
#  'apk emulators',
#  'best android emulator for pc',
#  'phone emulators',
#  'cell phone emulators',
#  'mobile phone emulator software',
#  'best android on pc',
#  'best smartphone emulator for pc',
#  'android gaming emulator for pc',
#  'android emulators best',
#  'mobile phone emulators for pc',
#  'android emulator pc',
#  'android pc player',
#  'emulator for mac android',
#  'android to pc emulator',
#  'best emulators for android on pc',
#  'android apk runner for pc',
#  'best emulator for pc to run android apps',
#  'best mobile app player for pc',
#  'android emulator for games on pc',
#  'android emulator best',
#  'android app player on pc',
#  'best mobile emulator',
#  'phone game emulator',
#  'best android emulators for mac',
#  'emulator apps',
#  'tablet emulator',
#  'virtual android on pc',
#  'android 4 emulator for pc',
#  'emulator android free',
#  'mobile emulator on pc',
#  'the most powerful android emulator for pc',
#  'desktop android emulator',
#  'the best android emulator for pc',
#  'android emulators windows',
#  'android app emulator for windows',
#  'emulator pc for android apk',
#  'android emulator for computer',
#  'emulator player',
#  'emulate phone on pc',
#  'best tablet emulator',
#  'app emulator for pc',
#  'laptop emulator for android',
#  'android on pc emulator',
#  'best android emulator pc 2020',
#  'emulator android pc',
#  'android emulator macos',
#  'new emulator for pc',
#  'download android emulator mac',
#  'emulator best',
#  'android emulator for pc gaming',
#  'android emulator on mac',
#  'free android emulator for windows',
#  'android em',
#  'android apps on pc emulator',
#  'os emulators',
#  'android vm windows',
#  'emulator android macbook',
#  'best emulator android',
#  'android emulator on pc download',
#  'download mobile emulator for pc',
#  'top app player for pc',
#  'apk to pc emulator',
#  'android emulator apk for pc',
#  'emulator android app',
#  'android pc emulator download',
#  'i android emulator',
#  'android emulator for pc windows',
#  'mobile gaming mouse for pc android emulators pc',
#  'app android emulator',
#  'android emulators for mac',
#  'mobile games emulator',
#  'mobile game player',
#  'android emulator for developers',
#  'emulator tablet',
#  'android games emulator for mac',
#  'best free emulator for pc',
#  'android emulator pc download',
#  'emulater downloads',
#  'phone emulator for mac',
#  'osx android emulator',
#  'android windows emulator',
#  'android software for pc',
#  'download android emulator for mac',
#  'mac apk emulator',
#  'free android gaming emulator for pc',
#  'macos android emulator',
#  'android app player for windows',
#  'free android emulator for pc',
#  'android emulator for pc windows 10',
#  'android emulator mac os',
#  'android emulator for mac',
#  'top 10 best emulator',
#  'mobile emulator for pc',
#  'android virtual machine windows',
#  'how to emulate android on pc',
#  'android tablet emulator',
#  'google play emulator',
#  'mac os android emulator',
#  'computer emulators for android',
#  'how to play android games on pc emulator',
#  'app emulator mac',
#  'top 5 best emulator for pc',
#  'emulator google play',
#  'run android apps on pc emulator',
#  'emulators for pc free',
#  'download mobile emulator',
#  'top 5 pc emulator',
#  'android emulator for mac os',
#  'android emulators windows 10',
#  'mobile emulator pc',
#  'mobile emulator android',
#  'android app emulator for mac',
#  'mobile gaming mouse for pc android emulators download',
#  'mobile gaming mouse for pc android emulators for pc',
#  'best mac android emulator',
#  'best emulators for pc 2018',
#  'mobile gaming mouse for pc android emulators for windows',
#  'mobile gaming mouse for pc android emulators mac',
#  'free emulators for pc',
#  'android screen emulator',
#  'windows pc android emulator',
#  'android android emulator',
#  'android games on windows emulator',
#  'mobile gaming mouse for pc android emulators windows',
#  'app emulator for mac',
#  'best android emulator for windows 10',
#  'official android emulator',
#  'android emulator for apps',
#  'android emulator app',
#  'app player android',
#  'phone emulator mac',
#  'mobile emulator for mac',
#  'android game player for pc',
#  'best app for running android on pc',
#  'best indian emulator for pc',
#  'mobile emulator',
#  'emulator for laptop',
#  'android emulator download mac',
#  'desktop emulator',
#  'mobile game emulator',
#  'windows to android emulator',
#  'android emulator for windows free',
#  'free android emulator on pc',
#  'emulator for pc',
#  'windows apk emulator',
#  'emulators for android studio',
#  'free emulator pc',
#  'play android games on pc emulator',
#  'emulator for android to play pc games',
#  '10 best emulator for pc',
#  'best android emulator for gaming windows 10',
#  'android simulator',
#  'best android emulator app',
#  'emulator pc to android',
#  'emulator apk for pc',
#  'android launcher for pc',
#  'phone emulator android',
#  'app emulator android',
#  'mobile emulator download',
#  'easy android emulator',
#  'mobile game pc emulator',
#  'android emulator for mac free',
#  'android games on pc emulator download',
#  'list of android emulator',
#  'best pc emulator for android',
#  'list of android emulators',
#  'app player for pc',
#  'emulate android on mac',
#  'top 5 emulator',
#  'new emulators for pc',
#  'best emulator for android to play pc games',
#  'emulate laptop to android',
#  'download phone emulator for pc',
#  'windows android emulator',
#  'pc gaming emulator for android',
#  'emulator software for pc',
#  'best emulator for pc download',
#  'emulator for android apps',
#  'emulate android',
#  'emulators for windows pc',
#  'mobile android emulator',
#  'windowsandroid emulator',
#  'android emulator pc games',
#  'android emulator to play mobile games on pc',
#  'android for pc emulator download',
#  'emulate android apps on windows',
#  'emulator list for pc',
#  'android emulator mac',
#  'emulater',
#  'emulater download',
#  'android emulator',
#  'android apk emulator',
#  'virtual machine android emulator',
#  'download android emulator pc',
#  'android emulators for pc free download',
#  'mobile game emulator for pc',
#  'best android emulators for windows 10',
#  'best mobile game emulator',
#  'best android emulator windows 10',
#  'phone simulator app',
#  'android app on pc emulator',
#  'best android emulator for mac',
#  'android emulator for mac download',
#  'android emulators mac',
#  'android-emulator',
#  'best android emulator for windows 10 for gaming',
#  'emulate tablet',
#  'virtual android emulator',
#  'play store emulator',
#  'android device emulators',
#  'android device emulator',
#  'best laptop emulators',
#  'top 1 emulator for pc',
#  'mobile game player for pc',
#  'emulator for pc gaming',
#  '5 best emulator android for pc',
#  'download android emulator for windows',
#  'how to run android apps on pc with emulator',
#  'download android emulator for pc',
#  'android emulators for windows 10',
#  'emulators for windows',
#  'emulator for games on pc',
#  'emulator android',
#  'android emulator google',
#  'software emulator',
#  'emulators for windows 10',
#  'best android emulator 2018',
#  'best app for pc to run android app',
#  'android virtual phone',
#  'android studio emulators',
#  'emulators for pc windows 10',
#  'best pc to phone',
#  'best win 10 android emulator',
#  'best emulator for windows 10',
#  'emulator tablet android',
#  'android app emulator for windows 10',
#  'google play pc emulator',
#  'google android emulator',
#  'android on emulator',
#  'android p for pc',
#  'top emulators for pc',
#  'popular emulators',
#  'android emulator mac download',
#  'mobile device emulator download',
#  'best android emulator for windows 10 to play games',
#  'what is android emulator for pc',
#  'google play store emulator',
#  'free android emulator windows',
#  'emulator software',
#  'android emulator for macbook',
#  'emulator for games',
#  'emulator android mac',
#  'samsung emulator for pc',
#  'android emulator for download',
#  'software for android on pc',
#  'app for pc to run android app',
#  'android windows 10 emulator',
#  'android on mac emulator',
#  'android emulator for windows 10',
#  'best pc emulator for pc',
#  'what is the best android emulator for windows 10',
#  'android emulator mac free',
#  'apps for running android apps on pc',
#  'software which run android apps on pc',
#  'google emulator',
#  'android emulator tablet',
#  'emulator for tablet',
#  'android emulator download for pc',
#  'apk player',
#  'apk emulator for windows 10',
#  'best emulator for pc',
#  'android for mac emulator',
#  'best smooth android emulator for pc',
#  'emulators apk',
#  'android emulator for pc download',
#  'android phone emulator for windows 10',
#  'android games player for pc software',
#  'virtual android on windows 10',
#  'apk player for pc',
#  'best application to run android apps on pc',
#  'phone emulator download',
#  'best emulator',
#  'best free emulators for pc',
#  'pc emulators for android',
#  'best android emulator 2021',
#  'android emulator pc windows 10',
#  'apk emulator mac',
#  'mobile simulator app',
#  'virtual android app',
#  'the best emulator for pc',
#  'best gaming emulator for pc',
#  'mobile app runner for pc',
#  'emu for pc',
#  'free mobile app simulator',
#  'pc emulator for phone',
#  'emulator on pc',
#  'android emulator download',
#  'best android emulator 2019',
#  'apps player for pc',
#  'top ten emulator for pc',
#  'apps that run android apps on pc',
#  'virtual emulator',
#  'desktop emulator for android',
#  'free emulator for pc',
#  'download android emulator',
#  'android emulation',
#  'emulator tool',
#  'mobile in pc',
#  'android app runner for pc',
#  'emulador for pc',
#  'best emulator to play pc games on android',
#  'best software to install android apps on pc',
#  'mobile for pc',
#  'emulator for android studio',
#  'apple android emulator',
#  'app players for pc',
#  'emulator os for pc',
#  'emulator android on mac',
#  'android software for computers',
#  'emulator mac android',
#  'emulador android pc',
#  'download apk emulator',
#  'mobile device simulator windows',
#  'avd emulator',
#  'emulator laptop',
#  'best android for pc',
#  'apk runner for pc download',
#  'android app emulator for windows 11',
#  'apk pc player',
#  'android emulator for macos',
#  'windows 10 android emulator',
#  'android studio emulator',
#  'best android apps free download to pc',
#  'best emulator mac',
#  'android emulator for windows 1',
#  'android virtual device emulator',
#  'emulators for pc games',
#  'list emulators',
#  'android emulator windows 10',
#  'virtual android device',
#  'android app runner',
#  'android emulator for developer',
#  'best browser android emulator',
#  'all emulator',
#  'android emulator for windows phone',
#  'download emulator android for pc',
#  'emulator download android',
#  'free android emulator for windows 10',
#  'android software in pc',
#  'android virtual machine',
#  'simple android emulator',
#  'emulator for computer',
#  'emulators for the pc',
#  'android emulators free download',
#  'best emulator for windows 11',
#  'free android emulator windows 10',
#  'emulator windows',
#  'android emulator for windows 11',
#  'laptop emulators',
#  'pc emulator for android',
#  "android studio's emulator",
#  'pc emulator for windows',
#  'free emulators downloads',
#  'android game emulator',
#  'mac emulator for android',
#  'pc to android software',
#  'gaming emulator for pc',
#  'android 10 emulator',
#  'download apk player for pc',
#  'windows android emulator download',
#  'vm android emulator',
#  'emulate pc on android',
#  'android games to pc emulator free download',
#  'mac emulator android',
#  'app to open android on pc',
#  'android emulator for win 10',
#  'best pc emulator for android apk',
#  'emulator apk',
#  'virtual android apps',
#  'android 8 emulator',
#  'player emulator',
#  'android emulator free download',
#  'best emulators for laptop',
#  'pc emulator software',
#  'gaming emulator for mac',
#  'android emulator options',
#  'download emulator',
#  'list emulator',
#  'android virtual machine windows 10',
#  'best emulator for windows',
#  'virtual android phone',
#  'emulators for pc',
#  'pc software android',
#  'fastest android emulator for windows 10',
#  'emulators for windows 11',
#  'virtual mobile emulator',
#  'android software pc',
#  'how to android emulator windows',
#  'best virtual android for android',
#  'app player',
#  'best emulator for pc free download',
#  'run android game',
#  'pc for android software',
#  'best smooth emulator for pc',
#  'windows 11 emulators',
#  'android games play pc app',
#  'emulation software for pc',
#  'android on pc software',
#  'emulation tablet',
#  'free emulator for android download',
#  'app for android on pc',
#  'fastest emulator android',
#  'fastest android emulator',
#  'pc emulator windows',
#  'best free android emulator for windows 10',
#  'test android app on pc',
#  'best mobile emulator for testing',
#  'best emulation pc',
#  'best emulator for mac',
#  'device emulators',
#  'game emulators for pc',
#  'emulator pc',
#  'android software to pc',
#  'android emulators apk',
#  'android vm',
#  'android emulator with google play',
#  'install android emulators',
#  'android app for pc',
#  'pc games on android emulator free',
#  'android 11 emulator for pc',
#  'virtual android',
#  'android emulator not for gaming',
#  'mobile on pc',
#  'gaming pc emulator',
#  'pc android app',
#  'lite android emulator',
#  'new emulator',
#  'gaming emulator',
#  'downloadable emulators',
#  'play android apps on pc',
#  'android emulator virtual machine',
#  'free pc emulator for android',
#  'best emulators for windows 10',
#  'top emulators',
#  'emulators',
#  'android software on pc',
#  'emulator free download for android',
#  'best emulation phone',
#  'best mac emulators',
#  'free pc emulator',
#  'apps to use android on pc',
#  'best fast emulator for pc',
#  'android emulator with play store',
#  'android games emulator for windows 7',
#  'download emulators',
#  'android 11 emulator',
#  'pc app player',
#  'download emulator android',
#  'emulator for android games on pc free download',
#  'emulator download for android',
#  'download emulator android pc',
#  'emulator android for windows phone',
#  'emulator android windows 10 64 bit',
#  'best game emulator for pc',
#  'game player pc',
#  'pc emulator for android free download',
#  'android mobile site emulator',
#  'windows on android emulator',
#  'app android for pc',
#  'online apk player',
#  'best app for playing pc games on android',
#  'emulador de android pc',
#  'download mobile simulator',
#  'android emulator for pc free download',
#  'game emulator for pc',
#  'emulator for windows 10',
#  'best emulator pc',
#  'pc emulator',
#  'emu pc',
#  'best android emulator for windows 11',
#  'emulator emulator',
#  'emulator games for pc',
#  'download emulator pc',
#  'best game emulators',
#  'good emulators',
#  'play android games on mac',
#  'android tablet windows emulator',
#  'android emulator light',
#  'run android on mac',
#  'download free emulator',
#  'emulator game apk',
#  'emulator for windows 11',
#  'top 5 pc emulator for android',
#  'play android on pc',
#  'microsoft android emulator',
#  'virtual emulator for android',
#  'game player for pc',
#  'free emulators download',
#  'emulators on pc',
#  'pc to android app',
#  'emulator computers',
#  'emulator',
#  'desktop android app',
#  'emulator gaming',
#  'emulator for pc windows 10',
#  "what's the best emulator for pc",
#  'android emulator 2018',
#  'android pc emulator bluestacks',
#  'best emulator machine',
#  'macintosh emulator android',
#  'newest emulators',
#  'best emulators for mac',
#  'android app on pc',
#  'fast android emulator',
#  'virtual phone android',
#  'emulador android en pc',
#  'android emulator for pc download windows 10',
#  'best emulator windows',
#  'pc emulator for android apk',
#  'smooth emulator for pc',
#  'fast emulator for android',
#  'android games on pc software download',
#  'emus emulator',
#  'virtual pc android',
#  'android emulator pc download windows 10',
#  'lightweight android emulator',
#  'computer emulator for android',
#  'android games play in pc software download',
#  'best emulators for windows',
#  'bluestacks phone emulator',
#  'best emulator tablet',
#  'emulator windows for android',
#  'emulators windows',
#  'emulator os',
#  'download android emulator for windows 10',
#  'new emulators',
#  'free android emulator on pc and mac download nox player',
#  'device emulator android',
#  'free game emulator for pc',
#  'android apps for pc',
#  'emulator download pc',
#  'android windows emulator download',
#  'emulator download',
#  'free android emulator on pc and mac-download nox player',
#  'game emulator',
#  'android for windows',
#  'android emulator for pc windows 10 free download',
#  'android emulator windows phone',
#  'windows 10 emulator android',
#  '64 bit android emulators',
#  'pc game on android emulator',
#  'android app for desktop',
#  'best emulation software',
#  'android game emulator download',
#  'emulator in android',
#  'run apps on the android emulator',
#  'good emulators for pc',
#  'best emulators for pc',
#  'windows 7 android emulator',
#  'pc emulator for android download',
#  'google play store android emulator',
#  'best emulators windows',
#  'microsoft emulator for android',
#  'app android on pc',
#  'download pc emulator',
#  'mobile apps for pc',
#  'light android emulator',
#  'mobile simulator',
#  'pc game emulator for android',
#  'best pc emulators',
#  'android desktop app',
#  'android emulator for windows download',
#  'best game emulators for pc',
#  'app emulator for pc free download',
#  'windows 10 emulator for windows 11',
#  'best macbook emulator',
#  'download android on pc',
#  'android app pc',
#  'best android emulator for windows 10 free download',
#  'pc emulator apk',
#  'emulator download mac',
#  'what is android emulators',
#  'emulator download free',
#  'android apps on a pc',
#  'game emulators for mac',
#  'bluestacks review 2022',
#  'best android computer',
#  'game emulators mac',
#  'emulador bluestacks',
#  'android emulator for android',
#  'android emulator fast',
#  'best android tablet for emulation',
#  'run android apps on pc software download',
#  'emulator for pc download',
#  'download emulators for pc',
#  'emulator for android apk',
#  'apk android emulator',
#  'games emulators',
#  'virtual for android',
#  'android emulator for windows 10 pc free download',
#  'pc emulators',
#  'safe android emulators',
#  'emulator for android free download',
#  'android emulator windows 10 free download',
#  'lightest android emulator',
#  'android app computer',
#  'android emulator apk',
#  'android app in pc',
#  'android emulator google play store',
#  'pc emulator on android',
#  'android virtual',
#  'android virtual desktop',
#  'best emulators 2023',
#  'best emulators pc',
#  'android emulator play store',
#  'best emulators for macbook',
#  'best windows emulators for android',
#  'top 10 apps to play pc games on android',
#  'android emulator lightweight',
#  'android windows phone emulator',
#  'bluestacks android emulator for mac',
#  'emulators download',
#  'top 20 emulators for pc',
#  'mobile app for pc',
#  'android emulator windows download',
#  'gaming emulator pc',
#  'android emulator google play',
#  'download android pc',
#  'safest android emulator',
#  'download emulator for pc',
#  'pc gaming emulator',
#  'faster android emulator',
#  'mobile emulator for pc free download',
#  'android computer app',
#  'game emulator pc',
#  'light apk emulator for pc',
#  'emulator android download',
#  'android on pc app',
#  'mobile for computer',
#  'application to run android apps on pc',
#  'emulator for pc games',
#  'windows emulator android',
#  'running android apps on pc',
#  'android emulator for android apk',
#  'safe android emulator',
#  'tablet simulator',
#  'best lightweight emulator for pc',
#  'emulator download for pc',
#  'android emulator for windows 10 free',
#  'download game emulator for pc',
#  'emulador nox',
#  'download mobile pc',
#  'android emulator lightest',
#  'android phone virtual machine',
#  'virtual machine android',
#  'android virtual machine for android',
#  'software pc android',
#  'download pc emulator for android',
#  'android on a mac',
#  'software for installing android apps on pc',
#  'pc emu',
#  'pc emulator for windows 10',
#  'small android emulator',
#  'run android apps on windows android studio',
#  'pc games emulator download',
#  'mobile emulator bluestacks',
#  'best light emulator for pc',
#  'android computer apps',
#  'android app for computer',
#  'is andy emulator safe',
#  'pc to android apps',
#  'download android in pc',
#  'memu the best android emulator for pc',
#  'virtual windows android',
#  'android emulator pc bluestacks',
#  'emulators pc',
#  'emulator games pc',
#  'best pc emulator',
#  'best emulation',
#  'bluestacks the best android emulator for pc',
#  'game emulator download for pc',
#  'bluestacks mobile emulator',
#  'mac android apps',
#  'ld player mac',
#  'best mac emulator',
#  'android app to pc',
#  'emulators for windows phone',
#  'computer emulators',
#  'emulator mac download',
#  'emulate mobile',
#  'android dev emulator',
#  'best emulator games for pc',
#  'pc game emulator download',
#  'android /emulated',
#  'nox android emulator',
#  'free pc games emulator',
#  'android emulator lite',
#  'mobile pc app',
#  'pc games on android emulator',
#  'ld player free android emulator on pc',
#  'android on pc download',
#  'ldplayer fastest android emulator for pc',
#  'virtual machine for android phone',
#  'run android apps on pc software',
#  'android apps pc',
#  'install android emulator',
#  'pc mobile app',
#  'android studio android emulator',
#  'apk emulator for windows 10 free download',
#  'best online android emulator free',
#  'android 12 emulator for pc',
#  'how to run android apps in pc',
#  'apps like gameloop',
#  'computer emulator games',
#  'run android app on pc',
#  'software pc to android',
#  'ldplayer best gaming android emulator on pc',
#  'run android apps in pc',
#  'bluestacks android emulator mac',
#  'smart phone simulator',
#  'game emulators',
#  'best virtual machine for android',
#  'play apps on pc',
#  'emulator android nox',
#  'pc software for android',
#  'windows 10 emulators',
#  'android apps play on pc',
#  'fast emulator android',
#  'nox player pc emulator',
#  'pc emulation software',
#  'windows phone simulator',
#  'android games emulator for low end pc',
#  'windows emulators for android',
#  'pc game player for android',
#  'memu emulador',
#  'emulation on pc',
#  'emulator machine',
#  'android virtual machine on android',
#  'memu play mac',
#  'how to use android emulators',
#  'download android games pc',
#  'emulator computer',
#  'game android pc',
#  'best tablet for emulators',
#  'android emulator on android',
#  'bluestacks free emulator for pc',
#  'best ios emulator for android 2018',
#  'lite apk emulator for pc',
#  'best android emulator for low-end pc',
#  'standalone android emulator',
#  'how to play android games on pc without emulator and os',
#  'mobile app simulator free',
#  'low and pc emulator',
#  'nox emulador',
#  'emulator free download',
#  'all emulators for pc',
#  'run an android app on pc',
#  'free download android emulator for windows 10',
#  'best android emulator for pc free download ldplayer on windows',
#  'game emulator for pc download',
#  'run android apps on pc',
#  'what is android emulator',
#  'game emulator for mac',
#  'nox android emulator pc',
#  'android app run in pc',
#  'android to pc software',
#  'virtual windows for android',
#  ...]

# %%
with open("keywords.txt", 'w') as f:
    for i in original_keywords:
        f.write(i + '\n')

# %% [markdown]
# # OpenRouter

# %%
from basic_cleaner import clean

original_content_of_website= clean(url)
original_content_of_website
# Out:
# 'The best Android emulators for PC and Mac of 2023 - Android AuthorityAffiliate links on Android Authority may earn us a commission.  The best Android emulators for PC and Mac of 2023Play games, do productive things, and run Android apps and games right from your computer.By Joe Hindy•August 4, 2023Joe Hindy / Android AuthorityEmulating Android on a computer has never been easier, and with the increasing popularity of Android apps, it’s not surprising that many people are looking for the best Android emulators for games, productivity, or app development. To help you find the right option for you, we’ve compiled this list of the best Android emulators for PC and Mac that are currently available.The list is quite a bit shorter than it used to be. Many of the top Android emulators have gone out of business without much in the way of replacements. Microsoft’s  will likely cause the list to shorten even more as people migrate to the easiest option. For step-by-step instructions, check out our guide to . The best Android emulators for PC and Mac              PROMOTED BlueStacks Price: Free   is known by many users to be the most comprehensive Android app player in the market, and with good reason. Aside from running on both Windows and Mac, this emulator comes jam-packed with a ton of features to improve the gamer’s experience.Its most popular features include\xa0the Keymapping Tool to create customized control schemes, the Instance Manager through which you can create multiple instances of the emulator and run several games simultaneously, and quality-of-life features like Eco Mode, which help to reduce resource consumption while running the most demanding games. It’s also the safest emulator out there, with certified GDPR compliance — your data is always safe with them.The most recent version, , is the lightest and fastest the emulator has ever been, delivering high-performance gaming even on low-end devices. The latest version addresses some of the most common complaints of the previous version — namely, the fact that it can feel bloated, especially when running on inferior hardware. Try it right now for yourself and discover why BlueStacks has a community of over 500 million gamers around the world!  Interested in more? Check out . Android Studio Price: FreeJoe Hindy / Android AuthorityAndroid Studio is the best Android emulator for app developers. Technically, Android Studio is an IDE. It comes with an emulator via the Android Virtual Device function. You can create nearly any device you want and use it to test your app. Regular people can also use this as an emulator, and performance actually isn’t half bad once you get through the setup. We played some games and used some apps without much difficulty. That said, it doesn’t have the extra support for keyboards that gaming-focused emulators have.Setup is a bit complicated at first, and using everything may require a week or two of learning. However, after that, this is a solid overall product, and many developers use it to develop apps you use every day. It’s also one of the few emulators capable of running the latest versions of Android. It comes with the Play Store, but you have to build an AVD with the Play Store icon in order to use it.Android Studio does have some competition in this space.  and  both perform more or less the same task. They are IDEs with built-in emulators so you can test your apps out. Xamarin is good because it’s cross-platform between Android and iOS. Genymotion’s big claim to fame is its scalability which allows for sharding and parallel testing. We think Android Studio is the best, but you have options in the development space. Bliss OS Price: FreeBliss OS has come a long way since it first made an appearance on this list, and today it’s definitely one of the better Android emulators out there. There are three different ways to use it. The first is a live boot option where you boot it off of a flash drive. Secondly, you can install it as a partition  ...

# %%
from summa import summarizer
trimmed_content= summarizer.summarize(original_content_of_website, words=500)
trimmed_content= trimmed_content.replace('\n', '')
trimmed_content
# Out:
# 'The best Android emulators for PC and Mac of 2023Play games, do productive things, and run Android apps and games right from your computer.By Joe Hindy•August 4, 2023Joe Hindy / Android AuthorityEmulating Android on a computer has never been easier, and with the increasing popularity of Android apps, it’s not surprising that many people are looking for the best Android emulators for games, productivity, or app development.To help you find the right option for you, we’ve compiled this list of the best Android emulators for PC and Mac that are currently available.The list is quite a bit shorter than it used to be.The best Android emulators for PC and Mac              PROMOTED BlueStacks Price: Free   is known by many users to be the most comprehensive Android app player in the market, and with good reason.Android Studio Price: FreeJoe Hindy / Android AuthorityAndroid Studio is the best Android emulator for app developers.It’s also one of the few emulators capable of running the latest versions of Android.Bliss OS Price: FreeBliss OS has come a long way since it first made an appearance on this list, and today it’s definitely one of the better Android emulators out there.That should allow you to play most, if not all, of the most recent games and use almost every app available.In other words, if you can get through the installation, Bliss is a fairly versatile option.LDPlayer 9 Price: FreeJoe Hindy / Android AuthorityLDPlayer is a gamer-focused emulator, but you can run other stuff on it as well.MeMU Play Price: FreeJoe Hindy / Android AuthorityMeMU Play is one of the older Android emulators on the list.MuMu Player Price: FreeJoe Hindy / Android AuthorityMuMu Player is another gaming-focused emulator from NetEase, a developer of many popular mobile games like Onmyoji, Vikingard, and others.It played our test games with a few issues, but it may be related to my test PC running on older hardware.The stable version of PrimeOS runs Android 7.a few hundred games are supported at the time of writing, but once Google Play supports Windows 11 in full, we don’t think any emulator is going to be as good as Windows 11 unless you need power-user tools like keymapping, which Windows 11 doesn’t offer at this time.Why use an Android emulator?There are three main uses for an Android emulator: gaming, app development, and productivity.Some of the more hardcore mobile gamers will also run their games in an Android emulator to give their phone a break, or use it to multi-instance farm.The second most popular use case is for app development.It helps developers test on a wide range of devices and screen sizes before launch, ensuring fewer bugs.The last use of Android emulators is productivity.Plus, some  at running Android apps than emulators.That said, some apps like Instagram limit features outside of the mobile space, so using an Android emulator is still sometimes the best option.'

# %%
import openai

openai.api_base = "https://openrouter.ai/api/v1"
openai.api_key = "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"

# %%
# response = openai.ChatCompletion.create(
#     model='gpt-3.5-turbo',
#     messages=[
#         {'role': 'user', 'content': 'Count to 100, with a comma between each number and no newlines. E.g., 1, 2, 3, ...'}
#     ],
#     temperature=0,
#     stream=True  # again, we set stream=True
# )

# %% [markdown]
# ## GPT 3.5

# %%
response = openai.ChatCompletion.create(
        model="openai/gpt-3.5-turbo", # Optional (user controls the default)
        messages=[
                    {"role": "user", "content": f"Can you suggest organic keywords for high seo ranking from the following content: \n{trimmed_content}"},
                ],
            # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
            #         "X-Title": $YOUR_APP_NAME },
            headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
                    "X-Title": "Deepankar" },
)
reply = response.choices[0].message

# %%
reply.content.split('\n')
# Out:
# ['- Android emulators for PC and Mac',
#  '- Best Android emulators for games',
#  '- Best Android emulators for productivity',
#  '- Emulating Android on a computer',
#  '- Android apps and games for PC and Mac',
#  '- Android emulator for app developers',
#  '- Running Android apps on a computer',
#  '- Best Android emulator options',
#  '- BlueStacks Android app player',
#  '- Android Studio emulator for developers',
#  '- Bliss OS Android emulator',
#  '- LDPlayer 9 gamer-focused emulator',
#  '- MeMU Play Android emulator',
#  '- MuMu Player gaming-focused emulator',
#  '- PrimeOS Android emulator for Windows 11',
#  '- Uses of Android emulators: gaming, app development, productivity',
#  '- Testing apps on different devices with Android emulators',
#  '- Using Android emulators for productivity',
#  '- Benefits of running Android apps on emulators',
#  '- Running Instagram and other mobile apps on an Android emulator']

# %% [markdown]
# ## GPT-3.5 Turbo 16k

# %%
response = openai.ChatCompletion.create(
        model="openai/gpt-3.5-turbo-16k", # Optional (user controls the default)
        messages=[
                    {"role": "user", "content": f"Can you suggest organic keywords for high seo ranking from the following content: \n{original_content_of_website}"},
                ],
            # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
            #         "X-Title": $YOUR_APP_NAME },
            headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
                    "X-Title": "Deepankar" },
)
reply = response.choices[0].message

# %%
reply.content.split('\n')
# Out:
# ['- Best Android emulators for PC and Mac',
#  '- Android emulators for games',
#  '- Android emulators for app development',
#  '- Emulating Android on a computer',
#  '- Android app player for PC and Mac',
#  '- Best Android emulator features',
#  '- Lightest and fastest Android emulator',
#  '- Certified GDPR compliance',
#  '- Android Studio for app developers',
#  '- IDE with built-in emulator',
#  '- Xamarin and Genymotion as Android emulator alternatives',
#  '- Bliss OS as a versatile Android emulator',
#  '- GameLoop for gaming',
#  '- LDPlayer as a gamer-focused emulator',
#  '- MeMU Play for multiple instances and keyboard mapping',
#  '- MuMu Player for mobile game support',
#  '- NoxPlayer with keyboard mapping',
#  '- PrimeOS as a full Android-powered desktop',
#  '- Windows 11 ability to run Android apps',
#  '- Advantages of using an Android emulator',
#  '- Former Android emulators on the list and their current status']

# %% [markdown]
# ## openai/gpt-4

# %%
response = openai.ChatCompletion.create(
        model="openai/gpt-4", # Optional (user controls the default)
        messages=[
                    {"role": "user", "content": f"Can you suggest organic keywords for high seo ranking from the following content: \n{trimmed_content}"},
                ],
            # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
            #         "X-Title": $YOUR_APP_NAME },
            headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
                    "X-Title": "Deepankar" },
)
reply = response.choices[0].message

# %%
reply.content.split('\n')
# Out:
# ['1. Best Android Emulators 2023',
#  '2. Android Apps on PC and Mac',
#  '3. Android Emulators for Gaming and Productivity',
#  '4. Android Emulators for App Developers ',
#  '5. Emulating Android on Computer',
#  '6. Comprehensive Android App Players ',
#  '7. Android Studio Emulator',
#  '8. Bliss OS Android Emulator',
#  '9. LDPlayer 9 for PC Gaming',
#  '10. MeMU Play Android Emulator',
#  '11. MuMu Player Emulator',
#  '12. PrimeOS for Android Gaming',
#  '13. Why use an Android Emulator?',
#  '14. Multi-instance Farming on Android Emulator',
#  '15. Android Emulator for Device Testing',
#  '16. Android Emulators for Increased Productivity',
#  '17. Android Emulation on Windows 11',
#  '18. Running Instagram on Android Emulator. ',
#  '19. Android Authority Emulator Reviews',
#  '20. Free Android Emulators for PC and Mac.']

# %% [markdown]
# ## openai/gpt-4-32k

# %%
response = openai.ChatCompletion.create(
        model="openai/gpt-4-32k", # Optional (user controls the default)
        messages=[
                    {"role": "user", "content": f"Can you suggest organic keywords for high seo ranking from the following content: \n{original_content_of_website}"},
                ],
            # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
            #         "X-Title": $YOUR_APP_NAME },
            headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
                    "X-Title": "Deepankar" },
)
reply = response.choices[0].message

# %%
reply.content.split('\n')
# Out:
# ['1. Best Android emulators',
#  '2. Android emulators for PC',
#  '3. Android emulators for Mac ',
#  '4. Android apps on PC ',
#  '5. Android Authority emulators review',
#  '6. Best gaming Android emulators',
#  '7. Android emulators for app development ',
#  '8. Android Studio emulator',
#  '9. Gameloop Android emulator',
#  '10. Bliss OS Android emulator',
#  '11. Android emulators of 2023',
#  '12. BlueStacks emulator for Windows and Mac',
#  '13. High-performance Android emulators',
#  '14. Android emulators for Windows 11',
#  '15. Running Android apps on computer',
#  '16. Safe Android emulators',
#  '17. Cross-platform Android emulators',
#  '18. Open-source Android emulators',
#  '19. LDPlayer Android emulator ',
#  '20. Using Android emulators for productivity.']

# %% [markdown]
# ## anthropic/claude-2

# %%
response = openai.ChatCompletion.create(
        model="anthropic/claude-2", # Optional (user controls the default)
        messages=[
                    {"role": "user", "content": f"Can you suggest organic keywords for high seo ranking from the following content: \n{trimmed_content}"},
                ],
            # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
            #         "X-Title": $YOUR_APP_NAME },
            headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
                    "X-Title": "Deepankar" },
)
reply = response.choices[0].message

# %%
reply.content.split('\n')
# Out:
# [' Here are some suggestions for organic keywords based on the content provided:',
#  '',
#  '- android emulator for pc',
#  '- best android emulator for windows ',
#  '- android emulator for mac',
#  '- top android emulators',
#  '- android emulator for gaming',
#  '- android emulator for developers',
#  '- android emulator for apps',
#  '- free android emulator ',
#  '- android emulator windows 11',
#  '- android studio emulator',
#  '- bluestacks android emulator',
#  '- ldplayer android emulator',
#  '- memu android emulator ',
#  '- mumu android emulator',
#  '- primeos android emulator',
#  '- bliss os emulator',
#  '- android emulator uses',
#  '- android emulators for productivity',
#  '- android emulators for gaming',
#  '- android emulators for app testing',
#  '- android emulator vs windows 11']

# %%
response = openai.ChatCompletion.create(
        model="anthropic/claude-2", # Optional (user controls the default)
        messages=[
                    {"role": "user", "content": f"Can you suggest organic keywords for high seo ranking from the following content: \n{original_content_of_website}"},
                ],
            # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
            #         "X-Title": $YOUR_APP_NAME },
            headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
                    "X-Title": "Deepankar" },
)
reply = response.choices[0].message
reply.content.split('\n')
# Out:
# [' Here are some potential organic keyword suggestions for your content:',
#  '',
#  '- android emulators for pc',
#  '- best android emulators for pc ',
#  '- android emulator for windows',
#  '- android emulator for mac',
#  '- android emulator for gaming',
#  '- android emulator for app development',
#  '- top android emulators',
#  '- free android emulators',
#  '- android emulator reviews',
#  '- windows android emulator',
#  '- mac android emulator',
#  '- android emulator vs simulator',
#  '- android virtual device emulator',
#  '- best android emulator for productivity',
#  '',
#  'The focus seems to be on android emulators, so keywords related to that along with qualifiers like "best", "top", "free", "for windows/mac/pc" etc. would be good options. Mentioning specific uses like gaming, development and productivity helps too. Reviews and comparisons like "android emulator vs simulator" can also work. Hope these suggestions help! Let me know if you need any clarification or have additional questions.']

# %% [markdown]
# ## anthropic/claude-instant-v1

# %%
response = openai.ChatCompletion.create(
        model="anthropic/claude-instant-v1", # Optional (user controls the default)
        messages=[
                    {"role": "user", "content": f"Can you suggest organic keywords for high seo ranking from the following content: \n{original_content_of_website}"},
                ],
            # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
            #         "X-Title": $YOUR_APP_NAME },
            headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
                    "X-Title": "Deepankar" },
)
reply = response.choices[0].message
reply.content.split('\n')
# Out:
# [' Here are some organic keywords that could rank well for this content:',
#  '',
#  '- Best Android emulators ',
#  '- Android emulators for PC',
#  '- Android emulators for Mac',
#  '- Top Android emulators',
#  '- Game emulators for Android',
#  '- Emulators to play Android games on PC',
#  '- Android emulators for gaming',
#  '- Android emulating software',
#  '- Android app emulators for PC',
#  '- Run Android apps on computer',
#  '- Android emulator reviews',
#  '- Android virtual machines',
#  '- Android virtualization software',
#  '- Android productivity tools for PC',
#  '- Android app development tools',
#  '',
#  'Some of the embedded keywords that could also rank well:',
#  '',
#  '- Bluestacks',
#  '- Android Studio ',
#  '- Bliss OS',
#  '- GameLoop',
#  '- LDPlayer',
#  '- MeMU Play',
#  '- MuMu Player ',
#  '- NoxPlayer',
#  '- PrimeOS',
#  '- Windows 11 Android',
#  '',
#  'I tried to focus on keywords that describe the main topics covered - finding the best emulators, using emulators for gaming, development and productivity. Let me know if you need any other suggestions.']

# %% [markdown]
# ## google/palm-2-chat-bison

# %%
response = openai.ChatCompletion.create(
        model="google/palm-2-chat-bison", # Optional (user controls the default)
        messages=[
                    {"role": "user", "content": f"Can you suggest organic keywords for high seo ranking from the following content: \n{trimmed_content}"},
                ],
            # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
            #         "X-Title": $YOUR_APP_NAME },
            headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
                    "X-Title": "Deepankar" },
)
reply = response.choices[0].message

# %%
reply.content.split('\n')
# Out:
# ['* best android emulators',
#  '* android emulator',
#  '* android emulator for pc',
#  '* android emulator for mac',
#  '* best android emulator for gaming',
#  '* best android emulator for development',
#  '* best android emulator for productivity',
#  '* android emulator 2023',
#  '* android emulator list',
#  '* android emulator comparison']

# %% [markdown]
# ## google/palm-2-chat-bison

# %%
response = openai.ChatCompletion.create(
        model="google/palm-2-chat-bison", # Optional (user controls the default)
        messages=[
                    {"role": "user", "content": f"Can you suggest organic keywords for high seo ranking from the following content: \n{original_content_of_website}"},
                ],
            # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
            #         "X-Title": $YOUR_APP_NAME },
            headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
                    "X-Title": "Deepankar" },
)
reply = response.choices[0].message

# %%
reply.content.split('\n')
# Out:
# ['Here are some keywords that you can use for high seo ranking:',
#  '',
#  '* Android emulator',
#  '* Best Android emulator',
#  '* Windows 11 Android emulator',
#  '* BlueStacks',
#  '* NoxPlayer',
#  '* LDPlayer',
#  '* MeMU Play',
#  '* MuMu Player',
#  '* PrimeOS',
#  '* Bliss OS',
#  '* GameLoop',
#  '* Android Studio',
#  '* Xamarin',
#  '* Genymotion',
#  '* ARChon',
#  '* Google Play',
#  '* Amazon Appstore',
#  '* Productivity',
#  '* App development',
#  '* Gaming']

# %%
response = openai.ChatCompletion.create(
        model="google/palm-2-codechat-bison", # Optional (user controls the default)
        messages=[
                    {"role": "user", "content": f"Can you suggest organic keywords for high seo ranking from the following content: \n{trimmed_content}"},
                ],
            # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
            #         "X-Title": $YOUR_APP_NAME },
            headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
                    "X-Title": "Deepankar" },
)
reply = response.choices[0].message
reply.content.split('\n')
# Out:
# ['* best android emulators',
#  '* android emulators for pc',
#  '* android emulators for mac',
#  '* best android emulator for gaming',
#  '* best android emulator for app development',
#  '* best android emulator for productivity',
#  '* how to use an android emulator',
#  '* why use an android emulator']

# %% [markdown]
# ## google/palm-2-codechat-bison

# %%
response = openai.ChatCompletion.create(
        model="google/palm-2-codechat-bison", # Optional (user controls the default)
        messages=[
                    {"role": "user", "content": f"Can you suggest organic keywords for high seo ranking from the following content: \n{trimmed_content}"},
                ],
            # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
            #         "X-Title": $YOUR_APP_NAME },
            headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
                    "X-Title": "Deepankar" },
)
reply = response.choices[0].message
reply.content.split('\n')
# Out:
# ['* best android emulators',
#  '* android emulators for pc',
#  '* android emulators for mac',
#  '* best android emulator for gaming',
#  '* best android emulator for app development',
#  '* best android emulator for productivity',
#  '* how to use an android emulator',
#  '* why use an android emulator']

# %% [markdown]
# ## meta-llama/llama-2-13b-chat

# %%
response = openai.ChatCompletion.create(
        model="meta-llama/llama-2-13b-chat", # Optional (user controls the default)
        messages=[
                    {"role": "user", "content": f"Can you suggest organic keywords for high seo ranking from the following content: \n{trimmed_content}"},
                ],
            # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
            #         "X-Title": $YOUR_APP_NAME },
            headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
                    "X-Title": "Deepankar" },
)
reply = response.choices[0].message
reply.content.split('\n')
# Out:
# ['Sure, I can help you with that! Here are some organic keywords that you can use to improve your SEO ranking for the content you provided:',
#  '',
#  '1. "Android emulators for PC and Mac"',
#  '2. "best Android emulators"',
#  '3. "Android']

# %% [markdown]
# ## meta-llama/llama-2-70b-chat

# %%
response = openai.ChatCompletion.create(
        model="meta-llama/llama-2-70b-chat", # Optional (user controls the default)
        messages=[
                    {"role": "user", "content": f"Can you suggest organic keywords for high seo ranking from the following content: \n{original_content_of_website}"},
                ],
            # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
            #         "X-Title": $YOUR_APP_NAME },
            headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
                    "X-Title": "Deepankar" },
)
reply = response.choices[0].message
reply.content.split('\n')
# Out:
# ['Here are some organic keywords that can help improve the SEO ranking of the article:',
#  '',
#  '1. Android emulators for PC and Mac',
#  '2. Best Android emulators',
#  '3. BlueStacks',
#  '4. Android Studio',
#  '5. Bliss OS',
#  '6. Genym']

# %% [markdown]
# ## nousresearch/nous-hermes-llama2-13b

# %%
response = openai.ChatCompletion.create(
        model="nousresearch/nous-hermes-llama2-13b", # Optional (user controls the default)
        messages=[
                    {"role": "user", "content": f"Can you suggest organic keywords for high seo ranking from the following content: \n{trimmed_content}"},
                ],
            # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
            #         "X-Title": $YOUR_APP_NAME },
            headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
                    "X-Title": "Deepankar" },
)
reply = response.choices[0].message
reply.content.split('\n')
# Out:
# ['I understand. Here are some organic keywords for high SEO ranking related to the content:',
#  '- Best Android emulators for PC and Mac',
#  '- Top Android emulators for gaming and productivity',
#  '- High-performance Android emulators for PC and Mac',
#  '- Em']

# %% [markdown]
# ## mancer/weaver

# %%
response = openai.ChatCompletion.create(
        model="mancer/weaver", # Optional (user controls the default)
        messages=[
                    {"role": "user", "content": f"Can you suggest organic keywords for high seo ranking from the following content: \n{trimmed_content}"},
                ],
            # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
            #         "X-Title": $YOUR_APP_NAME },
            headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
                    "X-Title": "Deepankar" },
)
# reply = response.choices[0].message
# reply.content.split('\n')
response
# Out:
# <OpenAIObject at 0x7f3c6e857100> JSON: {
#   "error": {
#     "code": 524,
#     "message": ""
#   }
# }

# %% [markdown]
# ## gryphe/mythomax-L2-13b

# %%
response = openai.ChatCompletion.create(
        model="gryphe/mythomax-L2-13b", # Optional (user controls the default)
        messages=[
                    {"role": "user", "content": f"Can you suggest organic keywords for high seo ranking from the following content: \n{trimmed_content}"},
                ],
            # headers={ "HTTP-Referer": $YOUR_SITE_URL, # To identify your app
            #         "X-Title": $YOUR_APP_NAME },
            headers={ "HTTP-Referer": "https://openrouter.ai/api/v1", # To identify your app
                    "X-Title": "Deepankar" },
)
reply = response.choices[0].message
reply.content.split('\n')
# Out:
# ['Sure, here are some organic keywords for high SEO ranking from the given content:',
#  '',
#  '1. Best Android emulators for PC and Mac',
#  '2. Emulate Android on a computer',
#  '3. Play games on PC',
#  '4. Productive things on Android emulators',
#  '5. Run Android apps and games on computer',
#  '6. Android app player',
#  '7. App development on Android emulators',
#  '8. Bluestacks emulator',
#  '9. Android Studio emulator',
#  '10. Bliss OS emulator',
#  '111. LDPlayer emulator',
#  '12. MeMU Play emulator',
#  '13. MuMu Player emulator',
#  '14. PrimeOS emulator',
#  '15. Gaming on Android emulators',
#  '16. Productivity on Android emulators',
#  '17. Multi-instance gaming',
#  '18. App testing on Android emulators',
#  '19. Developer tools on Android emulators',
#  '20. Instagram limitations on mobile space']
